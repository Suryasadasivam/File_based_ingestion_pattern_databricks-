# %%
CATALOG="file_based"
SCHEMA="ecommerce"

Bronze_table=f"{CATALOG}.{SCHEMA}.bronze_table"
Silver_table=f"{CATALOG}.{SCHEMA}.silver_table"
Gold_table=f"{CATALOG}.{SCHEMA}.gold_table"
Control_table=f"{CATALOG}.{SCHEMA}.control_table"
QUARANTINE_TABLE = f"{CATALOG}.{SCHEMA}.orders_quarantine"
BACKFILL_LOG     = f"{CATALOG}.{SCHEMA}.backfill_log"
RECON_LOG        = f"{CATALOG}.{SCHEMA}.reconciliation_log"

# %%
csv_checkpoint_path=f"/Volumes/{CATALOG}/{SCHEMA}/checkpoints/csv"
json_checkpoint_path=f"/Volumes/{CATALOG}/{SCHEMA}/checkpoints/json"
csv_schema_path=f"/Volumes/{CATALOG}/{SCHEMA}/schema/csv"
json_schema_path=f"/Volumes/{CATALOG}/{SCHEMA}/schema/json"
file_landing_path=f"/Volumes/{CATALOG}/{SCHEMA}/filelanding"
